# %% [markdown]
# # 1. O que é o Jupyter

# %% [markdown]
# ##### Opção #1: instalar no Windows
# ##### Opção #2: instalar no Linux (WSL)
# ##### Opção #3: instalar o Anaconda
# ##### Opção #4: instalar no Docker
# ##### Opção #5: Google Collab
# ===============================================================
# #### 1. instalar o ubuntu 18
# #### 2. sudo apt update && upgrade
# #### 3. sudo apt install python3 python3-pip ipython3
# #### 4. pip3 install --upgrade pip
# #### 5. pip3 install jupyter
# #### 6. vim ~/.bashrc
# #### 7. alias jupyter-notebook="~/.local/bin/jupyter-notebook --no-browser"
# #### 8. source ~/.bashrc
# #### 9. jupyter-notebook
# #### 10. Copia o link e abre no browser do Windows
# #### 11. Instalar o Pandas, Matplotlib e Seaborn

# %% [markdown]
# # 2. EDA

# %% [markdown]
# ![IA-2022-01-EDA-3.PNG](attachment:IA-2022-01-EDA-3.PNG)

# %% [markdown]
# ![IA-2022-01-EDA-1.PNG](attachment:IA-2022-01-EDA-1.PNG)

# %% [markdown]
# ![IA-2022-01-EDA-2.PNG](attachment:IA-2022-01-EDA-2.PNG)

# %% [markdown]
# # 3. Ler arquivos (Pandas)

# %% [markdown]
# # 4. Visualizar dados. Shape, head, tail. Sobrescrever nomes de colunas

# %% [markdown]
# # 5. Selecionar dados por colunas. Value counts. Valores únicos.

# %% [markdown]
# # 6. Obter estatísticas. Média, mediana.

# %% [markdown]
# # Exercício
#
# ## 1. Baixar o dataset do MovieLens (AVA)
# ## 2. Usar o Pandas para ler o arquivo "ratings"
# ## 3. Analisar as primeiras linhas do arquivo bem como o shape do dataframe
# ## 4. Sobrescrever os nomes das colunas
# ## 5. Analisar os valores únicos da coluna que contém a nota
# ## 6. Contar a quantidade de notas aplicadas para cada valor único de nota (value_counts())
# ## 7. Analisar a média das notas dos filmes

# %%
import pandas as pd

df_ratings = pd.read_csv('ratings.csv')
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_ratings.shape
# Out:
# (100836, 4)

# %%
df_ratings.rename(columns={'userId': 'user_id', 'movieId': 'movie_id', 'rating': 'ratings', 'timestamp': 'time'}, inplace=True)
df_ratings.head()
# Out:
#    user_id  movie_id  ratings       time
# 0        1         1      4.0  964982703
# 1        1         3      4.0  964981247
# 2        1         6      4.0  964982224
# 3        1        47      5.0  964983815
# 4        1        50      5.0  964982931

# %%
df_ratings['ratings'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
df_ratings['ratings'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: ratings, dtype: int64

# %%
df_ratings['ratings'].mean()
# Out:
# 3.501556983616962

# %% [markdown]
# # Parte 2: Respondendo perguntas

# %% [markdown]
# # 7. Análise exploratória
# ### a) Qual o percentual de pessoas que possui internet em casa (['Q025'].map({'A' : 'Não', 'B': 'Sim'}))?
# ### b) Qual a escolaridade da mãe dos candidatos (['Q002'].map({'A':'Nunca estudou', 'B':'Não completou EF', 'C':'Não completou EF', 'D':'Não completou EM', 'E':'Não completou ES', 'F':'Graduada', 'G':'Pós-graduada','H':'Não sabe'}))?
# ### c) Qual a renda familiar (['Q006'].map({'A':'Nenhuma renda', 'B':'Até 1.320', 'C':'Até 1.320',
#                                  'D':'Até 3.520', 'E':'Até 3.520', 'F':'Até 3.520', 'G':'Até 3.520',
#                                  'H':'Até 10.560','I':'Até 10.560', 'J':'Até 10.560','K':'Até 10.560',
#                                  'L':'Até 10.560','M':'Até 10.560','N':'Até 10.560',
#                                  'O':'Mais de 10.560','P':'Mais de 10.560','Q':'Mais de 10.560'}))?
# ### d) Qual o histograma de idades (matplotlib hist)?
# ### e) Como se comparam as notas de CH com MT?
# ### f) Qual a correlação entre as notas de CH e MT?
# ### g) Como se compara a renda familiar com a nota em MT?
# ### h) Como se compara a escolaridade da mãe com a nota em MT?
# ### i) Como se compara o local de residência com a nota em MT?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_enem = pd.read_csv('enem.csv', index_col=0)
df_enem = df_enem.reset_index(drop=True)
df_enem.head()
# Out:
#                                NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  \
# 0  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad    2016                  4314902
# 1  2c3acac4b33ec2b195d77e7c04a2d75727fad723    2016                  2304707
# 2  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568    2016                  2304400
# 3  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe    2016                  3304557
# 4  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268    2016                  1302603
#
#   NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 0            Porto Alegre                43               RS        24
# 1                  Granja                23               CE        17
# 2               Fortaleza                23               CE        21
# 3          Rio de Janeiro                33               RJ        25
# 4                  Manaus                13               AM        28
#
#   TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  ...  Q041  Q042 Q043  Q044 Q045  \
# 0       M              0.0            1  ...   5.0     A    A     A    A
# 1       F              0.0            3  ...   NaN     A    A     C    A
# 2       F              0.0            3  ...   NaN     A    A     A    A
# 3       F              0.0            0  ...   5.0     C    A     A    A
# 4       M              0.0            2  ...   NaN     A    A     A    A
#
#    Q046  Q047  Q048  Q049  Q050
# 0     A     A     A     B     D
# 1     B     A     A     C     A
# 2     C     A     A     B     A
# 3     A     D     A     A     A
# 4     A     A     A     A     A
#
# [5 rows x 166 columns]

# %%
df_enem['Q025'] = df_enem['Q025'].map({'A' : 'Não', 'B': 'Sim'})

# %%
df_enem['Q025'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# Sim    56.9%
# Não    43.1%
# Name: Q025, dtype: object

# %%
df_enem['Q002'] = df_enem['Q002'].map({'A':'Nunca estudou', 'B':'Não completou EF', 'C':'Não completou EF', 'D':'Não completou EM', 'E':'Não completou ES', 'F':'Graduada', 'G':'Pós-graduada','H':'Não sabe'})

# %%
plt.figure(figsize=(12, 10));
plt.hist(df_enem['Q002']);

# %%
df_enem['Q006'] = df_enem['Q006'].map({'A':'Nenhuma renda', 'B':'Até 1.320', 'C':'Até 1.320',
                             'D':'Até 3.520', 'E':'Até 3.520', 'F':'Até 3.520', 'G':'Até 3.520',
                             'H':'Até 10.560','I':'Até 10.560', 'J':'Até 10.560','K':'Até 10.560',
                             'L':'Até 10.560','M':'Até 10.560','N':'Até 10.560',
                             'O':'Mais de 10.560','P':'Mais de 10.560','Q':'Mais de 10.560'})

# %%
plt.figure(figsize=(12, 10));
plt.hist(df_enem['NU_IDADE'], bins = 20);

# %%
plt.figure(figsize = (12, 10))
sns.kdeplot(df_enem['NU_NOTA_MT'], shade = True, color = 'r');
sns.kdeplot(df_enem['NU_NOTA_CH'], shade = True, color = 'b');
plt.legend(['Matemática', 'Ciências Humanas']);

# %%
plt.figure(figsize = (12, 10))
sns.regplot(x=df_enem["NU_NOTA_CH"], y=df_enem["NU_NOTA_MT"]);

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(x="Q006", y="NU_NOTA_MT",
            data=df_enem)
sns.despine(offset=10, trim=True)

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(x="Q002", y="NU_NOTA_MT",
            data=df_enem)
sns.despine(offset=10, trim=True)

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(x="SG_UF_RESIDENCIA", y="NU_NOTA_MT",
            data=df_enem)
sns.despine(offset=10, trim=True)

# %% [markdown]
# # Exercício
#
# ## 1. Plotar um histograma das notas dos filmes notas.nota.plot(kind='hist')
# ## 2. Plotar um boxplot das notas dos filmes sns.boxplot(notas.nota)
# ## 3. Usar o describe() nas notas dos filmes
# ## 4. Ler o CSV de filmes usando Pandas
# ## 5. Renomear as colunas do dataframe
# ## 6. Rodar uma query para um filmeId query("filmeId==1")
# ## 7. Analisar a média das notas dos filmes 1 e 2
# ## 8. Agrupar os filmes pelo id groupby(by="filmeId") e analisar a média extraindo a coluna ["nota"]
# ## 9. Plotar as medias por filme usando .plot(kind='hist') do Pandas
# ## 10. Plotar usando seaborn boxplot das médias por filme
# ## 11. Plotar um seaborn distplot() das médias por filme.
# ## 12. Passar o parâmetro bins=10 para o distplot()
# ## 13. Usar o matplotlib.pyplot para plotar um hist() das médias por filme. Comparar com os outros gráficos. Aplicar um título .title("Meu Titulo")
# ## 14. Use .figure(figsize=(largura, altura)) do matplotlib.pyplot

# %%
df_ratings = pd.read_csv('ratings.csv')
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
plt.figure(figsize=(12, 10))
df_ratings.rating.plot(kind='hist');

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(df_ratings.rating);
# Out:
# /home/guicttram/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
df_movies = pd.read_csv('movies.csv')
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_movies = df_movies.rename(columns = {'movieId': 'movie_id'})
df_movies.head()
# Out:
#    movie_id                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_movies.query("movie_id==1")
# Out:
#    movie_id             title                                       genres
# 0         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
df_ratings.query("movieId==1").rating.mean()
# Out:
# 3.9209302325581397

# %%
df_ratings.query("movieId==2").rating.mean()
# Out:
# 3.4318181818181817

# %%
df_ratings.groupby(by="movieId").rating.mean()
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
plt.figure(figsize=(12, 10))
df_ratings.groupby(by="movieId").rating.mean().plot(kind='hist');

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(df_ratings.groupby(by="movieId").rating.mean());
# Out:
# /home/guicttram/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 10))
sns.distplot(df_ratings.groupby(by="movieId").rating.mean(), bins=10);
# Out:
# /home/guicttram/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12, 10))
plt.hist(df_ratings.groupby(by="movieId").rating.mean());
plt.title('Média por filme');
